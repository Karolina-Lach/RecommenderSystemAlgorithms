# %%
# !pip install -q tensorflow-recommenders
# !pip install -q --upgrade tensorflow-datasets
# !pip install -q scann

# %%
import os
import pprint
import tempfile
from typing import Dict, Text

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

import pandas as pd

# %%
import tensorflow_recommenders as tfrs

# %%
import pickle

# %% [markdown]
# # Constants

# %%
RATINGS_SMALL = "../EDA_files/ratings_small.parquet"
RECIPES_SMALL = "../EDA_files/recipes_small.parquet"
INDEX_TO_RECIPE_OBJ = "../EDA_files/index_to_recipe.obj"
RECIPE_TO_INDEX_OBJ = "../EDA_files/recipe_to_index.obj"

# %% [markdown]
# # Load data

# %%
recipes_small = pd.read_parquet(RECIPES_SMALL)
ratings_small = pd.read_parquet(RATINGS_SMALL)

# %%
with open('../EDA_files/ratings_small.obj', 'wb') as pickle_file:
     pickle.dump(ratings_small, pickle_file)

# %%
with open('../EDA_files/recipes_small.obj', 'wb') as pickle_file:
     pickle.dump(recipes_small, pickle_file)

# %% [markdown]
# # Prepare dataset

# %%
ratings_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401982 entries, 0 to 1401981
# Data columns (total 5 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   RecipeId       1401982 non-null  int32
#  1   AuthorId       1401982 non-null  int32
#  2   Rating         1401982 non-null  int32
#  3   Review         1401982 non-null  object
#  4   DateSubmitted  1401982 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int32(3), object(1)
# memory usage: 37.4+ MB

# %%
features = ['AuthorId', 'RecipeId']
ratings = tf.data.Dataset.from_tensor_slices((
            tf.cast(ratings_small[features].values, tf.int32),
            tf.cast(ratings_small['Rating'].values, tf.float32))
    )

# %%
ratings_dict = ratings_small[['AuthorId', 'RecipeId', 'Rating']].to_dict()

# %%
# ratings = (tf.data.Dataset.from_tensor_slices(ratings_dict))

# %%
ratings = ratings.map(lambda x : x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\UYTKOW~1\AppData\Local\Temp/ipykernel_2148/1321772210.py in <module>
# ----> 1 ratings = ratings.map(lambda x : x)
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2002         warnings.warn("The `deterministic` argument has no effect unless the "
#    2003                       "`num_parallel_calls` argument is specified.")
# -> 2004       return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2005     else:
#    2006       return ParallelMapDataset(
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5453     self._use_inter_op_parallelism = use_inter_op_parallelism
#    5454     self._preserve_cardinality = preserve_cardinality
# -> 5455     self._map_func = StructuredFunctionWrapper(
#    5456         map_func,
#    5457         self._transformation_name(),
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    4531         fn_factory = trace_tf_function(defun_kwargs)
#    4532
# -> 4533     self._function = fn_factory()
#    4534     # There is no graph to add in eager mode.
#    4535     add_to_graph &= not context.executing_eagerly()
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\eager\function.py in get_concrete_function(self, *args, **kwargs)
#    3242          or `tf.Tensor` or `tf.TensorSpec`.
#    3243     """
# -> 3244     graph_function = self._get_concrete_function_garbage_collected(
#    3245         *args, **kwargs)
#    3246     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3208       args, kwargs = None, None
#    3209     with self._lock:
# -> 3210       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3211       seen_names = set()
#    3212       captured = object_identity.ObjectIdentitySet(
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3390     arg_names = base_arg_names + missing_arg_names
#    3391     graph_function = ConcreteFunction(
# -> 3392         func_graph_module.func_graph_from_py_func(
#    3393             self._name,
#    3394             self._python_function,
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1141         _, original_func = tf_decorator.unwrap(python_func)
#    1142
# -> 1143       func_outputs = python_func(*func_args, **func_kwargs)
#    1144
#    1145       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in wrapped_fn(*args)
#    4508           attributes=defun_kwargs)
#    4509       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# -> 4510         ret = wrapper_helper(*args)
#    4511         ret = structure.to_tensor_list(self._output_structure, ret)
#    4512         return [ops.convert_to_tensor(t) for t in ret]
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in wrapper_helper(*args)
#    4438       if not _should_unpack(nested_args):
#    4439         nested_args = (nested_args,)
# -> 4440       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#    4441       if _should_pack(ret):
#    4442         ret = tuple(ret)
#
# C:\anaconda\envs\RecSys\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     697       except Exception as e:  # pylint:disable=broad-except
#     698         if hasattr(e, 'ag_error_metadata'):
# --> 699           raise e.ag_error_metadata.to_exception(e)
#     700         else:
#     701           raise
#
# TypeError: in user code:
#
#
#     TypeError: <lambda>() takes 1 positional argument but 2 were given

# %%
for x in ratings.take(10).as_numpy_iterator():
  pprint.pprint(x)
# Out:
# (array([2008,  992]), 5.0)
# (array([1634, 4384]), 4.0)
# (array([2046, 4523]), 2.0)
# (array([1773, 7435]), 5.0)
# (array([2085,   44]), 5.0)
# (array([2046, 5221]), 4.0)
# (array([ 2046, 13307]), 5.0)
# (array([2156,  148]), 0.0)
# (array([2046,  517]), 5.0)
# (array([2046, 4684]), 5.0)

# %%
interactions_dict = ratings_small.groupby(['AuthorId', 'RecipeId'])['Rating'].sum().reset_index()

# %%
interactions_dict
# Out:
#            AuthorId  RecipeId  Rating
# 0              1533      2137       5
# 1              1533      2585       1
# 2              1533      4213       5
# 3              1533      8857       5
# 4              1533     10332       5
# ...             ...       ...     ...
# 1401977  2002901749    153642       5
# 1401978  2002901759    363862       5
# 1401979  2002901787    128248       5
# 1401980  2002901848    264191       5
# 1401981  2002901938    411791       5
#
# [1401982 rows x 3 columns]

# %%
ratings_small[ratings_small.RecipeId==2137]
# Out:
#          RecipeId    AuthorId  Rating  \
# 10040        2137       27643       5
# 10772        2137       40237       5
# 11466        2137       10033       5
# 145848       2137        1533       5
# 152512       2137      195076       5
# 162142       2137       69474       5
# 229774       2137      215898       5
# 265215       2137      283787       5
# 270426       2137      254415       5
# 272458       2137       74987       5
# 386706       2137      353491       5
# 399038       2137      398694       4
# 423234       2137      235662       5
# 424682       2137      461552       4
# 547262       2137      504973       5
# 577735       2137      297546       4
# 584743       2137      557764       4
# 606154       2137       64322       5
# 620745       2137      326581       5
# 764034       2137      406503       5
# 785198       2137     1208848       5
# 788775       2137      935433       5
# 793109       2137      252816       0
# 800771       2137     1300836       5
# 803472       2137     1306315       0
# 813056       2137       17803       5
# 958970       2137       53932       0
# 984080       2137     1250920       5
# 992114       2137      335571       4
# 1062187      2137      125416       5
# 1226125      2137      439400       5
# 1395757      2137  2002640472       5
#
#                                                     Review  \
# 10040    I went searching the site for a fresh rhubarb ...
# 10772            just the recipe I am looking for - thanks
# 11466    !!!!!!This was fantastic!!!!!!!! The whole pie...
# 145848   OUTSTANDING was the only comments my guests ma...
# 152512   AWESOME and surprisingly easy.  I used vegan b...
# 162142   This is the only rhubarb pie I will ever use!!...
# 229774   Wonderful! Easy to make and very flavorful. I ...
# 265215   My husband and son loved it.  We did add Straw...
# 270426   Rated this recipe 5 stars for ease of preparat...
# 272458   Loved this pie. My favorite rhubarb pie is Str...
# 386706   I have been dubbed "official family pie queen"...
# 399038   I had no idea what a rhubarb was when I decide...
# 423234   This pie was perfectly delicious; not too swee...
# 424682   I made this using the cornstarch and had a dis...
# 547262   Best Rhubarb Pie,ever. We polished it off in n...
# 577735   Tasted delicious, but didn't set up at all!  N...
# 584743   Thank you YUM!  The only thing different I did...
# 606154   My husband went right out to water the rhubarb...
# 620745   I offered to make my Mom a pie or a cake for h...
# 764034   Have made this pie a number of times and follo...
# 785198   I have been searching for the perfect rhubarb ...
# 788775   This was so easy to make and was the best tast...
# 793109              I did not care for the citrus flavor..
# 800771   This is a fantastic recipe!  I think that it's...
# 803472   I followed the measurements very carefully and...
# 813056   A very good recipe but like cookinthewoods, ou...
# 958970   This pie did not set well for me.  I added 3 t...
# 984080   Really great rhubarb pie, kinda tart but not a...
# 992114   Was very good. I used a Tablespoon more corn s...
# 1062187  This recipe was fabulous!  I followed the advi...
# 1226125  Great pie.  Made it with just 1 cup of sugar a...
# 1395757  Delicious! I added 1/8 cup more sugar (we didn...
#
#                     DateSubmitted
# 10040   2002-04-29 19:42:58+00:00
# 10772   2002-05-09 15:26:22+00:00
# 11466   2002-05-19 16:25:57+00:00
# 145848  2005-02-27 09:30:26+00:00
# 152512  2005-03-30 09:48:16+00:00
# 162142  2005-05-12 13:30:14+00:00
# 229774  2006-02-07 11:20:37+00:00
# 265215  2006-06-18 16:18:14+00:00
# 270426  2006-07-03 19:12:53+00:00
# 272458  2006-07-09 13:48:21+00:00
# 386706  2007-05-13 14:32:39+00:00
# 399038  2007-06-08 12:13:44+00:00
# 423234  2007-07-29 03:46:37+00:00
# 424682  2007-08-01 11:48:21+00:00
# 547262  2008-03-10 19:44:40+00:00
# 577735  2008-05-07 20:15:18+00:00
# 584743  2008-05-24 17:30:46+00:00
# 606154  2008-06-29 21:38:57+00:00
# 620745  2008-07-27 19:09:22+00:00
# 764034  2009-04-09 15:56:52+00:00
# 785198  2009-05-19 23:08:27+00:00
# 788775  2009-05-27 15:07:47+00:00
# 793109  2009-06-03 18:31:10+00:00
# 800771  2009-06-19 16:18:20+00:00
# 803472  2009-06-25 12:32:25+00:00
# 813056  2009-07-15 18:56:11+00:00
# 958970  2010-05-10 05:31:25+00:00
# 984080  2010-07-03 21:42:59+00:00
# 992114  2010-08-01 02:25:02+00:00
# 1062187 2011-05-08 21:19:53+00:00
# 1226125 2013-09-23 05:03:25+00:00
# 1395757 2020-05-19 21:13:05+00:00

# %%
interactions_dict = {name: np.array(value) for name, value in interactions_dict.items()}
interactions = tf.data.Dataset.from_tensor_slices(interactions_dict)

# %%
interactions = interactions.map(lambda x: {'user_id' : x['AuthorId'], 
                                            'product_id' : x['RecipeId'], 
                                            'quantity' : float(x['Rating']),})

# %%
for x in interactions.take(10).as_numpy_iterator():
  pprint.pprint(x)
# Out:
# {'product_id': 2137, 'quantity': 5.0, 'user_id': 1533}
# {'product_id': 2585, 'quantity': 1.0, 'user_id': 1533}
# {'product_id': 4213, 'quantity': 5.0, 'user_id': 1533}
# {'product_id': 8857, 'quantity': 5.0, 'user_id': 1533}
# {'product_id': 10332, 'quantity': 5.0, 'user_id': 1533}
# {'product_id': 10457, 'quantity': 5.0, 'user_id': 1533}
# {'product_id': 10554, 'quantity': 5.0, 'user_id': 1533}
# {'product_id': 10721, 'quantity': 5.0, 'user_id': 1533}
# {'product_id': 11914, 'quantity': 5.0, 'user_id': 1533}
# {'product_id': 12027, 'quantity': 5.0, 'user_id': 1533}

# %%
tf.random.set_seed(42)
shuffled = interactions.shuffle(100_000, seed=42, reshuffle_each_iteration=False)

train = shuffled.take(80_000)
test = shuffled.take(80_000).take(20_000)
